# %%
import numpy as np
import pandas as pd
import matplotlib as plt
dataset = pd.read_csv('D:\diabetes_prediction_dataset.csv')
x=dataset.iloc[:,:-1]
print(x)

# %%
#(https://www.kaggle.com/datasets/iammustafatz/diabetes-prediction-dataset), I have used this dataset for the model

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifierv #using randomforest as it deals well with datasets that has both regression and classification pattern

# Load the data
data = pd.read_csv("D:\diabetes_prediction_dataset.csv")  # Replace this with the actual path to your CSV file

# Preprocess the data
# Encode categorical features
categorical_features = ["gender", "hypertension", "heart_disease", "smoking_history"]
for feature in categorical_features:
    data[feature] = LabelEncoder().fit_transform(data[feature])



# Standardize numerical features
numerical_features = ["age", "bmi", "HbA1c_level", "blood_glucose_level"]
scaler = StandardScaler()
data[numerical_features] = scaler.fit_transform(data[numerical_features])

# Separate features and target
features = data.drop("diabetes", axis=1)
target = data["diabetes"]

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Train a model (Random Forest in this example)
model = RandomForestClassifier(n_estimators=100)#estimators u can take as yr choice 
model.fit(X_train, y_train)

# Evaluate the model performance
y_pred = model.predict(X_test)
from sklearn.metrics import accuracy_score, f1_score
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1-score:", f1_score(y_test, y_pred))

# Make predictions on new data
# Replace with your new data points
new_data = pd.DataFrame({
    "gender": ["Female"],
    "age": [50],
    "hypertension": [1],
    "heart_disease": [0],
    "smoking_history": ["never"],
    "bmi": [25],
    "HbA1c_level": [6.0],
    "blood_glucose_level": [120]
})

# Preprocess new data similarly to how you preprocessed the original data
# Encode categorical features in new_data
for feature in categorical_features:
    new_data[feature] = LabelEncoder().fit_transform(new_data[feature])

new_prediction = model.predict(new_data)
print("Predicted diabetes for new data:", new_prediction[0])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier

# Load the data
data = pd.read_csv("D:\diabetes_prediction_dataset.csv")  # Replace this with the actual path to your CSV file

# Preprocess the data
# Encode categorical features
categorical_features = ["gender", "hypertension", "heart_disease", "smoking_history"]
for feature in categorical_features:
    data[feature] = LabelEncoder().fit_transform(data[feature])

# Handle missing values (if any)


# Standardize numerical features
numerical_features = ["age", "bmi", "HbA1c_level", "blood_glucose_level"]
scaler = StandardScaler()
data[numerical_features] = scaler.fit_transform(data[numerical_features])

# Separate features and target
features = data.drop("diabetes", axis=1)
target = data["diabetes"]

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Train a model (Random Forest in this example)
model = RandomForestClassifier(n_estimators=100)
model.fit(X_train, y_train)

# Evaluate the model performance
y_pred = model.predict(X_test)
from sklearn.metrics import accuracy_score, f1_score
print("Accuracy:", accuracy_score(y_test, y_pred))
print("F1-score:", f1_score(y_test, y_pred))

# Make predictions on new data
# Replace with your new data points
new_data = pd.DataFrame({
    "gender": ["male"],
    "age": [20],
    "hypertension": [0],
    "heart_disease": [0],
    "smoking_history": ["never"],
    "bmi": [18],
    "HbA1c_level": [4.8],
    "blood_glucose_level": [80]
})

# Preprocess new data similarly to how you preprocessed the original data
# Encode categorical features in new_data
for feature in categorical_features:
    new_data[feature] = LabelEncoder().fit_transform(new_data[feature])

new_prediction = model.predict(new_data)
print("Predicted diabetes for new data:", new_prediction[0])
